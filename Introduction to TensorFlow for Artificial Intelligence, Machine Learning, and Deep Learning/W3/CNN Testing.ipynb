# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(60000, 28, 28, 1)
x_train = x_train/255.0

x_test = x_test.reshape(10000, 28,28,1)
x_test= x_test/255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu',input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
model.fit(x_train, y_train, epochs=10)
test_loss, test_acc = model.evaluate(x_test, y_test)
print(test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2995 - acc: 0.9098
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0535 - acc: 0.9837
# Epoch 3/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0312 - acc: 0.9904
# Epoch 4/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0205 - acc: 0.9937
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0125 - acc: 0.9962
# Epoch 6/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0107 - acc: 0.9962
# Epoch 7/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0054 - acc: 0.9985
# Epoch 8/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0048 - acc: 0.9984
# Epoch 9/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0037 - acc: 0.9988
# Epoch 10/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0026 - acc: 0.9991
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0634 - acc: 0.9863
# 0.986299991607666

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu',input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['acc'])
model.fit(x_train,y_train, epochs=10)
test_loss,test_acc = model.evaluate(x_test,y_test)
print(test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2895 - acc: 0.9112
# Epoch 2/10
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0493 - acc: 0.9840
# Epoch 3/10
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0290 - acc: 0.9910
# Epoch 4/10
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0207 - acc: 0.9938
# Epoch 5/10
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.0125 - acc: 0.9960
# Epoch 6/10
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0075 - acc: 0.9975
# Epoch 7/10
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0068 - acc: 0.9978
# Epoch 8/10
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0057 - acc: 0.9980
# Epoch 9/10
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.0050 - acc: 0.9983
# Epoch 10/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0036 - acc: 0.9991
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0661 - acc: 0.9849
# 0.9848999977111816

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')

])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['acc'])
model.fit(x_train,y_train, epochs=10)
test_loss,test_acc = model.evaluate(x_test, y_test)
print(test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.2681 - acc: 0.9175
# Epoch 2/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0391 - acc: 0.9879
# Epoch 3/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0274 - acc: 0.9920
# Epoch 4/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0172 - acc: 0.9946
# Epoch 5/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0128 - acc: 0.9963
# Epoch 6/10
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.0099 - acc: 0.9970
# Epoch 7/10
# 1875/1875 [==============================] - 38s 21ms/step - loss: 0.0089 - acc: 0.9972
# Epoch 8/10
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0084 - acc: 0.9973
# Epoch 9/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0062 - acc: 0.9980
# Epoch 10/10
#  - ETA: 40s - loss: 0.0197 - acc: 0.9963
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0315 - acc: 0.9934
# 0.993399977684021

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('acc') > .95):
            print("Model has reached 95% accuracy")
            self.model.stop_training=True

# %%
callback = myCallback()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')

])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='acc')
model.fit(x_train, y_train, epochs=10, callbacks=callback)
test_loss, test_acc = model.evaluate(x_test, y_test)
print(test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.2791 - acc: 0.9130
# Model has reached 95% accuracy
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0359 - acc: 0.9879
# 0.9879000186920166
