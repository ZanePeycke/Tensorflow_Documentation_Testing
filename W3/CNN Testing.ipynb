# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(60000, 28, 28, 1)
x_train = x_train/255.0

x_test = x_test.reshape(10000, 28,28,1)
x_test= x_test/255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu',input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
model.fit(x_train, y_train, epochs=10)
test_loss, test_acc = model.evaluate(x_test, y_test)
print(test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2944 - acc: 0.9177
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0480 - acc: 0.9856
# Epoch 3/10
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0281 - acc: 0.9916
# Epoch 4/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0191 - acc: 0.9938
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0106 - acc: 0.9971
# Epoch 6/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0085 - acc: 0.9975
# Epoch 7/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0061 - acc: 0.9979
# Epoch 8/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0037 - acc: 0.9990
# Epoch 9/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0041 - acc: 0.9988
# Epoch 10/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0042 - acc: 0.9988
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0613 - acc: 0.9871
# 0.9871000051498413
